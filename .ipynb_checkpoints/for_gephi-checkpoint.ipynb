# %%
import numpy as np
import pandas as pd
import string
from collections import Counter
import networkx as nx
import matplotlib.pyplot as plt 


def file_open(path):
    print('Start read data from file')
    input_read = pd.read_excel(path,skip_blank_lines=True) 
    df = pd.DataFrame(input_read)
    print('Read data')
    return df

# %%
def relation_data(path):
    res = []
    df = file_open(path)
      
    for index,data in enumerate(df["issue_ID"],start=1):
        if index == df.shape[0]:
            break
        if df["issue_ID"][index]== df["issue_ID"][index-1]:
            res.append((df["commenter"][index-1],df["commenter"][index]))
    return res

# %%
path = "data/closed_comment.xlsx"
data = relation_data(path)
c_directed = Counter(data)    #directed relation  ex: [a,b] != [b,a]
[sorted(tuple(i)) for i in data]
# Out:
# Start read data from file
# Read data

# %%
data
# Out:
# [('MeshCollider', 'wuchiachih'),
#  ('wuchiachih', 'MeshCollider'),
#  ('MeshCollider', 'wuchiachih'),
#  ('wuchiachih', 'sipa'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('vinnyvoo', 'ch4ot1c'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('vinnyvoo', 'ch4ot1c'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('vinnyvoo', 'vinnyvoo'),
#  ('dmchess', 'DocOBITCOIN'),
#  ('promag', 'hamnaz'),
#  ('hamnaz', 'fanquake'),
#  ('promag', 'bunnguyen2410'),
#  ('bunnguyen2410', 'MarcoFalke'),
#  ('MarcoFalke', 'ken2812221'),
#  ('e-nexus', 'bunnguyen2410'),
#  ('bunnguyen2410', 'e-nexus'),
#  ('e-nexus', 'bunnguyen2410'),
#  ('bunnguyen2410', 'MeshCollider'),
#  ('e-nexus', 'bunnguyen2410'),
#  ('jonasschnelli', 'msgilligan'),
#  ('Crypto2', 'ryanofsky'),
#  ('ryanofsky', 'al-maisan'),
#  ('al-maisan', 'promag'),
#  ('promag', 'nopara73'),
#  ('nopara73', 'promag'),
#  ('promag', 'promag'),
#  ('promag', 'nopara73'),
#  ('nopara73', 'promag'),
#  ('promag', 'nopara73'),
#  ('nopara73', 'promag'),
#  ('promag', 'RHavar'),
#  ('RHavar', 'RHavar'),
#  ('RHavar', 'promag'),
#  ('promag', 'jnewbery'),
#  ('jnewbery', 'nopara73'),
#  ('achow101', 'coinsmith'),
#  ('fanquake', 'MarcoFalke'),
#  ('RHavar', 'sipa'),
#  ('sipa', 'MarcoFalke'),
#  ('MarcoFalke', 'jnewbery'),
#  ('jnewbery', 'RHavar'),
#  ('RHavar', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('laanwj', 'kristapsk'),
#  ('kristapsk', 'laanwj'),
#  ('laanwj', 'promag'),
#  ('promag', 'RHavar'),
#  ('RHavar', 'kristapsk'),
#  ('kristapsk', 'promag'),
#  ('promag', 'nopara73'),
#  ('nopara73', 'promag'),
#  ('promag', 'nopara73'),
#  ('nopara73', 'jb55'),
#  ('jb55', 'sipa'),
#  ('sipa', 'jnewbery'),
#  ('jnewbery', 'nopara73'),
#  ('nopara73', 'MarcoFalke'),
#  ('MarcoFalke', 'nopara73'),
#  ('nopara73', 'sipa'),
#  ('sipa', 'nopara73'),
#  ('nopara73', 'promag'),
#  ('Sjors', 'sangaman'),
#  ('sangaman', 'sangaman'),
#  ('theuni', 'jonasschnelli'),
#  ('jonasschnelli', 'theuni'),
#  ('theuni', 'fanquake'),
#  ('fanquake', 'theuni'),
#  ('ReneFroger', 'assafadar'),
#  ('assafadar', 'ReneFroger'),
#  ('ReneFroger', 'assafadar'),
#  ('MarcoFalke', 'isghe'),
#  ('isghe', 'achow101'),
#  ('MarcoFalke', 'RHavar'),
#  ('RHavar', 'fanquake'),
#  ('fanquake', 'sdaftuar'),
#  ('sdaftuar', 'RHavar'),
#  ('ken2812221', 'molxyz'),
#  ('molxyz', 'MarcoFalke'),
#  ('MarcoFalke', 'molxyz'),
#  ('molxyz', 'sipsorcery'),
#  ('sipsorcery', 'molxyz'),
#  ('molxyz', 'sipsorcery'),
#  ('sipsorcery', 'molxyz'),
#  ('molxyz', 'molxyz'),
#  ('molxyz', 'sipsorcery'),
#  ('sipsorcery', 'molxyz'),
#  ('molxyz', 'sipsorcery'),
#  ('sipsorcery', 'molxyz'),
#  ('molxyz', 'molxyz'),
#  ('molxyz', 'molxyz'),
#  ('MarcoFalke', 'yzhou61'),
#  ('yzhou61', 'eserlxl'),
#  ('eserlxl', 'yzhou61'),
#  ('yzhou61', 'eserlxl'),
#  ('eserlxl', 'yzhou61'),
#  ('yzhou61', 'eserlxl'),
#  ('Ali8668', 'teknari'),
#  ('teknari', 'MarcoFalke'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'teknari'),
#  ('ken2812221', 'molxyz'),
#  ('MarcoFalke', 'sanket1729'),
#  ('sanket1729', 'laanwj'),
#  ('laanwj', 'MarcoFalke'),
#  ('MarcoFalke', 'sanket1729'),
#  ('sanket1729', 'MarcoFalke'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('DianJakaWidiawan', 'fanquake'),
#  ('scravy', 'ohhmm'),
#  ('ohhmm', 'sipa'),
#  ('sipa', 'scravy'),
#  ('scravy', 'ohhmm'),
#  ('ohhmm', 'MarcoFalke'),
#  ('jonasschnelli', 'laanwj'),
#  ('greenaddress', 'sanjays95'),
#  ('MarcoFalke', 'giaki3003'),
#  ('giaki3003', 'MarcoFalke'),
#  ('MarcoFalke', 'giaki3003'),
#  ('giaki3003', 'MarcoFalke'),
#  ('MarcoFalke', 'giaki3003'),
#  ('giaki3003', 'MarcoFalke'),
#  ('MarcoFalke', 'giaki3003'),
#  ('giaki3003', 'giaki3003'),
#  ('azetrom', 'sipa'),
#  ('MarcoFalke', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('laanwj', 'AkioNak'),
#  ('AkioNak', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('ken2812221', 'MarcoFalke'),
#  ('MarcoFalke', 'coinsmith'),
#  ('coinsmith', 'mmortal03'),
#  ('mmortal03', 'coinsmith'),
#  ('ken2812221', 'fanquake'),
#  ('fanquake', 'molxyz'),
#  ('molxyz', 'ken2812221'),
#  ('ken2812221', 'molxyz'),
#  ('kallewoof', 'AkioNak'),
#  ('AkioNak', 'AkioNak'),
#  ('AkioNak', 'kallewoof'),
#  ('kallewoof', 'AkioNak'),
#  ('AkioNak', 'practicalswift'),
#  ('practicalswift', 'practicalswift'),
#  ('practicalswift', 'Empact'),
#  ('Empact', 'ryanofsky'),
#  ('ryanofsky', 'kallewoof'),
#  ('kallewoof', 'kallewoof'),
#  ('kallewoof', 'Empact'),
#  ('Empact', 'AkioNak'),
#  ('AkioNak', 'practicalswift'),
#  ('practicalswift', 'kallewoof'),
#  ('kallewoof', 'practicalswift'),
#  ('practicalswift', 'MarcoFalke'),
#  ('MarcoFalke', 'ryanofsky'),
#  ('ryanofsky', 'practicalswift'),
#  ('practicalswift', 'ryanofsky'),
#  ('ryanofsky', 'practicalswift'),
#  ('practicalswift', 'practicalswift'),
#  ('practicalswift', 'practicalswift'),
#  ('practicalswift', 'kallewoof'),
#  ('ken2812221', 'alexander7567'),
#  ('alexander7567', 'ken2812221'),
#  ('ken2812221', 'fanquake'),
#  ('fanquake', 'alexeyneu'),
#  ('alexeyneu', 'sipa'),
#  ('sipa', 'alexeyneu'),
#  ('alexeyneu', 'MarcoFalke'),
#  ('kirillkovalenko', 'alexeyneu'),
#  ('alexeyneu', 'kirillkovalenko'),
#  ('kirillkovalenko', 'alexeyneu'),
#  ('NicolasDorier', 'NicolasDorier'),
#  ('sipa', 'MarcoFalke'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'Ayms'),
#  ('Ayms', 'MarcoFalke'),
#  ('MarcoFalke', 'Ayms'),
#  ('Ayms', 'fanquake'),
#  ('fanquake', 'Ayms'),
#  ('Ayms', 'MarcoFalke'),
#  ('MarcoFalke', 'sipa'),
#  ('sipa', 'Ayms'),
#  ('Ayms', 'MarcoFalke'),
#  ('MarcoFalke', 'Ayms'),
#  ('Ayms', 'Ayms'),
#  ('Ayms', 'Ayms'),
#  ('practicalswift', 'jmcorgan'),
#  ('jmcorgan', 'domob1812'),
#  ('domob1812', 'promag'),
#  ('promag', 'practicalswift'),
#  ('practicalswift', 'domob1812'),
#  ('domob1812', 'promag'),
#  ('promag', 'domob1812'),
#  ('domob1812', 'MarcoFalke'),
#  ('MarcoFalke', 'funasty1985'),
#  ('funasty1985', 'sipa'),
#  ('sipa', 'funasty1985'),
#  ('funasty1985', 'MarcoFalke'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'funasty1985'),
#  ('funasty1985', 'funasty1985'),
#  ('funasty1985', 'MarcoFalke'),
#  ('MarcoFalke', 'funasty1985'),
#  ('funasty1985', 'domob1812'),
#  ('domob1812', 'sipa'),
#  ('sipa', 'funasty1985'),
#  ('sipa', 'leishman'),
#  ('leishman', 'sipa'),
#  ('sipa', 'MarcoFalke'),
#  ('MarcoFalke', 'leishman'),
#  ('MarcoFalke', 'ken2812221'),
#  ('ken2812221', 'funasty1985'),
#  ('sipa', 'achow101'),
#  ('Derek701', 'SearchAndDestroy'),
#  ('SearchAndDestroy', 'TheBlueMatt'),
#  ('TheBlueMatt', 'laanwj'),
#  ('thelukemccarthy', 'MarcoFalke'),
#  ('MarcoFalke', 'cryptozeny'),
#  ('MarcoFalke', 'rhinogroup'),
#  ('rhinogroup', 'MarcoFalke'),
#  ('MarcoFalke', 'rhinogroup'),
#  ('MarcoFalke', 'syrius01'),
#  ('syrius01', 'sipa'),
#  ('isghe', 'fanquake'),
#  ('fanquake', 'jonasschnelli'),
#  ('jonasschnelli', 'fanquake'),
#  ('fanquake', 'Sjors'),
#  ('ken2812221', 'jamesob'),
#  ('MarcoFalke', 'GusevVasily'),
#  ('GusevVasily', 'GusevVasily'),
#  ('GusevVasily', 'TheBlueMatt'),
#  ('TheBlueMatt', 'MarcoFalke'),
#  ('MarcoFalke', 'GusevVasily'),
#  ('laanwj', 'MarcoFalke'),
#  ('MarcoFalke', 'laanwj'),
#  ('laanwj', 'kallewoof'),
#  ('kallewoof', 'achow101'),
#  ('jonasschnelli', 'DinoStray'),
#  ('jonasschnelli', 'nkostoulas'),
#  ('fanquake', 'bekarys0504'),
#  ('achow101', 'Sjors'),
#  ('Sjors', 'ken2812221'),
#  ('ken2812221', 'Sjors'),
#  ('Sjors', 'Sjors'),
#  ('Sjors', 'Sjors'),
#  ('Sjors', 'MarcoFalke'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'Sjors'),
#  ('Sjors', 'ken2812221'),
#  ('ken2812221', 'Sjors'),
#  ('Sjors', 'Sjors'),
#  ('Sjors', 'MarcoFalke'),
#  ('fanquake', 'Sjors'),
#  ('jonasschnelli', 'jonasschnelli'),
#  ('jonasschnelli', 'MarcoFalke'),
#  ('MarcoFalke', 'marcoagner'),
#  ('marcoagner', 'domob1812'),
#  ('domob1812', 'domob1812'),
#  ('ken2812221', 'sergeyklay'),
#  ('sergeyklay', 'ken2812221'),
#  ('ken2812221', 'sergeyklay'),
#  ('sergeyklay', 'sergeyklay'),
#  ('ken2812221', 'fanquake'),
#  ('fanquake', 'FIVIL'),
#  ('jonasschnelli', 'melaxon'),
#  ('melaxon', 'MeshCollider'),
#  ('MeshCollider', 'promag'),
#  ('ken2812221', 'Sjors'),
#  ('Sjors', 'ken2812221'),
#  ('ken2812221', 'Sjors'),
#  ('Sjors', 'Sjors'),
#  ('Sjors', 'laanwj'),
#  ('laanwj', 'theuni'),
#  ('theuni', 'Sjors'),
#  ('Sjors', 'jonasschnelli'),
#  ('jonasschnelli', 'MarcoFalke'),
#  ('MarcoFalke', 'LucaPaterlini'),
#  ('LucaPaterlini', 'sipa'),
#  ('sipa', 'LucaPaterlini'),
#  ('LucaPaterlini', 'MarcoFalke'),
#  ('MarcoFalke', 'crowdcoinChain'),
#  ('crowdcoinChain', 'jonasschnelli'),
#  ('jonasschnelli', 'MarcoFalke'),
#  ('MarcoFalke', 'sipsorcery'),
#  ('promag', 'ZexiFangkong'),
#  ('ZexiFangkong', 'fanquake'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'jtimon'),
#  ('StayCoolDK', 'efvhi'),
#  ('efvhi', 'sipa'),
#  ('sipa', 'efvhi'),
#  ('efvhi', 'sipa')]

# %%
# Out:
# [('MeshCollider', 'wuchiachih'),
#  ('MeshCollider', 'wuchiachih'),
#  ('MeshCollider', 'wuchiachih'),
#  ('sipa', 'wuchiachih'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('ch4ot1c', 'vinnyvoo'),
#  ('vinnyvoo', 'vinnyvoo'),
#  ('DocOBITCOIN', 'dmchess'),
#  ('hamnaz', 'promag'),
#  ('fanquake', 'hamnaz'),
#  ('bunnguyen2410', 'promag'),
#  ('MarcoFalke', 'bunnguyen2410'),
#  ('MarcoFalke', 'ken2812221'),
#  ('bunnguyen2410', 'e-nexus'),
#  ('bunnguyen2410', 'e-nexus'),
#  ('bunnguyen2410', 'e-nexus'),
#  ('MeshCollider', 'bunnguyen2410'),
#  ('bunnguyen2410', 'e-nexus'),
#  ('jonasschnelli', 'msgilligan'),
#  ('Crypto2', 'ryanofsky'),
#  ('al-maisan', 'ryanofsky'),
#  ('al-maisan', 'promag'),
#  ('nopara73', 'promag'),
#  ('nopara73', 'promag'),
#  ('promag', 'promag'),
#  ('nopara73', 'promag'),
#  ('nopara73', 'promag'),
#  ('nopara73', 'promag'),
#  ('nopara73', 'promag'),
#  ('RHavar', 'promag'),
#  ('RHavar', 'RHavar'),
#  ('RHavar', 'promag'),
#  ('jnewbery', 'promag'),
#  ('jnewbery', 'nopara73'),
#  ('achow101', 'coinsmith'),
#  ('MarcoFalke', 'fanquake'),
#  ('RHavar', 'sipa'),
#  ('MarcoFalke', 'sipa'),
#  ('MarcoFalke', 'jnewbery'),
#  ('RHavar', 'jnewbery'),
#  ('RHavar', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('kristapsk', 'laanwj'),
#  ('kristapsk', 'laanwj'),
#  ('laanwj', 'promag'),
#  ('RHavar', 'promag'),
#  ('RHavar', 'kristapsk'),
#  ('kristapsk', 'promag'),
#  ('nopara73', 'promag'),
#  ('nopara73', 'promag'),
#  ('nopara73', 'promag'),
#  ('jb55', 'nopara73'),
#  ('jb55', 'sipa'),
#  ('jnewbery', 'sipa'),
#  ('jnewbery', 'nopara73'),
#  ('MarcoFalke', 'nopara73'),
#  ('MarcoFalke', 'nopara73'),
#  ('nopara73', 'sipa'),
#  ('nopara73', 'sipa'),
#  ('nopara73', 'promag'),
#  ('Sjors', 'sangaman'),
#  ('sangaman', 'sangaman'),
#  ('jonasschnelli', 'theuni'),
#  ('jonasschnelli', 'theuni'),
#  ('fanquake', 'theuni'),
#  ('fanquake', 'theuni'),
#  ('ReneFroger', 'assafadar'),
#  ('ReneFroger', 'assafadar'),
#  ('ReneFroger', 'assafadar'),
#  ('MarcoFalke', 'isghe'),
#  ('achow101', 'isghe'),
#  ('MarcoFalke', 'RHavar'),
#  ('RHavar', 'fanquake'),
#  ('fanquake', 'sdaftuar'),
#  ('RHavar', 'sdaftuar'),
#  ('ken2812221', 'molxyz'),
#  ('MarcoFalke', 'molxyz'),
#  ('MarcoFalke', 'molxyz'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'molxyz'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'sipsorcery'),
#  ('molxyz', 'molxyz'),
#  ('molxyz', 'molxyz'),
#  ('MarcoFalke', 'yzhou61'),
#  ('eserlxl', 'yzhou61'),
#  ('eserlxl', 'yzhou61'),
#  ('eserlxl', 'yzhou61'),
#  ('eserlxl', 'yzhou61'),
#  ('eserlxl', 'yzhou61'),
#  ('Ali8668', 'teknari'),
#  ('MarcoFalke', 'teknari'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'teknari'),
#  ('ken2812221', 'molxyz'),
#  ('MarcoFalke', 'sanket1729'),
#  ('laanwj', 'sanket1729'),
#  ('MarcoFalke', 'laanwj'),
#  ('MarcoFalke', 'sanket1729'),
#  ('MarcoFalke', 'sanket1729'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('DianJakaWidiawan', 'fanquake'),
#  ('ohhmm', 'scravy'),
#  ('ohhmm', 'sipa'),
#  ('scravy', 'sipa'),
#  ('ohhmm', 'scravy'),
#  ('MarcoFalke', 'ohhmm'),
#  ('jonasschnelli', 'laanwj'),
#  ('greenaddress', 'sanjays95'),
#  ('MarcoFalke', 'giaki3003'),
#  ('MarcoFalke', 'giaki3003'),
#  ('MarcoFalke', 'giaki3003'),
#  ('MarcoFalke', 'giaki3003'),
#  ('MarcoFalke', 'giaki3003'),
#  ('MarcoFalke', 'giaki3003'),
#  ('MarcoFalke', 'giaki3003'),
#  ('giaki3003', 'giaki3003'),
#  ('azetrom', 'sipa'),
#  ('MarcoFalke', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('AkioNak', 'laanwj'),
#  ('AkioNak', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('laanwj', 'laanwj'),
#  ('MarcoFalke', 'ken2812221'),
#  ('MarcoFalke', 'coinsmith'),
#  ('coinsmith', 'mmortal03'),
#  ('coinsmith', 'mmortal03'),
#  ('fanquake', 'ken2812221'),
#  ('fanquake', 'molxyz'),
#  ('ken2812221', 'molxyz'),
#  ('ken2812221', 'molxyz'),
#  ('AkioNak', 'kallewoof'),
#  ('AkioNak', 'AkioNak'),
#  ('AkioNak', 'kallewoof'),
#  ('AkioNak', 'kallewoof'),
#  ('AkioNak', 'practicalswift'),
#  ('practicalswift', 'practicalswift'),
#  ('Empact', 'practicalswift'),
#  ('Empact', 'ryanofsky'),
#  ('kallewoof', 'ryanofsky'),
#  ('kallewoof', 'kallewoof'),
#  ('Empact', 'kallewoof'),
#  ('AkioNak', 'Empact'),
#  ('AkioNak', 'practicalswift'),
#  ('kallewoof', 'practicalswift'),
#  ('kallewoof', 'practicalswift'),
#  ('MarcoFalke', 'practicalswift'),
#  ('MarcoFalke', 'ryanofsky'),
#  ('practicalswift', 'ryanofsky'),
#  ('practicalswift', 'ryanofsky'),
#  ('practicalswift', 'ryanofsky'),
#  ('practicalswift', 'practicalswift'),
#  ('practicalswift', 'practicalswift'),
#  ('kallewoof', 'practicalswift'),
#  ('alexander7567', 'ken2812221'),
#  ('alexander7567', 'ken2812221'),
#  ('fanquake', 'ken2812221'),
#  ('alexeyneu', 'fanquake'),
#  ('alexeyneu', 'sipa'),
#  ('alexeyneu', 'sipa'),
#  ('MarcoFalke', 'alexeyneu'),
#  ('alexeyneu', 'kirillkovalenko'),
#  ('alexeyneu', 'kirillkovalenko'),
#  ('alexeyneu', 'kirillkovalenko'),
#  ('NicolasDorier', 'NicolasDorier'),
#  ('MarcoFalke', 'sipa'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('Ayms', 'MarcoFalke'),
#  ('Ayms', 'MarcoFalke'),
#  ('Ayms', 'MarcoFalke'),
#  ('Ayms', 'fanquake'),
#  ('Ayms', 'fanquake'),
#  ('Ayms', 'MarcoFalke'),
#  ('MarcoFalke', 'sipa'),
#  ('Ayms', 'sipa'),
#  ('Ayms', 'MarcoFalke'),
#  ('Ayms', 'MarcoFalke'),
#  ('Ayms', 'Ayms'),
#  ('Ayms', 'Ayms'),
#  ('jmcorgan', 'practicalswift'),
#  ('domob1812', 'jmcorgan'),
#  ('domob1812', 'promag'),
#  ('practicalswift', 'promag'),
#  ('domob1812', 'practicalswift'),
#  ('domob1812', 'promag'),
#  ('domob1812', 'promag'),
#  ('MarcoFalke', 'domob1812'),
#  ('MarcoFalke', 'funasty1985'),
#  ('funasty1985', 'sipa'),
#  ('funasty1985', 'sipa'),
#  ('MarcoFalke', 'funasty1985'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'funasty1985'),
#  ('funasty1985', 'funasty1985'),
#  ('MarcoFalke', 'funasty1985'),
#  ('MarcoFalke', 'funasty1985'),
#  ('domob1812', 'funasty1985'),
#  ('domob1812', 'sipa'),
#  ('funasty1985', 'sipa'),
#  ('leishman', 'sipa'),
#  ('leishman', 'sipa'),
#  ('MarcoFalke', 'sipa'),
#  ('MarcoFalke', 'leishman'),
#  ('MarcoFalke', 'ken2812221'),
#  ('funasty1985', 'ken2812221'),
#  ('achow101', 'sipa'),
#  ('Derek701', 'SearchAndDestroy'),
#  ('SearchAndDestroy', 'TheBlueMatt'),
#  ('TheBlueMatt', 'laanwj'),
#  ('MarcoFalke', 'thelukemccarthy'),
#  ('MarcoFalke', 'cryptozeny'),
#  ('MarcoFalke', 'rhinogroup'),
#  ('MarcoFalke', 'rhinogroup'),
#  ('MarcoFalke', 'rhinogroup'),
#  ('MarcoFalke', 'syrius01'),
#  ('sipa', 'syrius01'),
#  ('fanquake', 'isghe'),
#  ('fanquake', 'jonasschnelli'),
#  ('fanquake', 'jonasschnelli'),
#  ('Sjors', 'fanquake'),
#  ('jamesob', 'ken2812221'),
#  ('GusevVasily', 'MarcoFalke'),
#  ('GusevVasily', 'GusevVasily'),
#  ('GusevVasily', 'TheBlueMatt'),
#  ('MarcoFalke', 'TheBlueMatt'),
#  ('GusevVasily', 'MarcoFalke'),
#  ('MarcoFalke', 'laanwj'),
#  ('MarcoFalke', 'laanwj'),
#  ('kallewoof', 'laanwj'),
#  ('achow101', 'kallewoof'),
#  ('DinoStray', 'jonasschnelli'),
#  ('jonasschnelli', 'nkostoulas'),
#  ('bekarys0504', 'fanquake'),
#  ('Sjors', 'achow101'),
#  ('Sjors', 'ken2812221'),
#  ('Sjors', 'ken2812221'),
#  ('Sjors', 'Sjors'),
#  ('Sjors', 'Sjors'),
#  ('MarcoFalke', 'Sjors'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'Sjors'),
#  ('Sjors', 'ken2812221'),
#  ('Sjors', 'ken2812221'),
#  ('Sjors', 'Sjors'),
#  ('MarcoFalke', 'Sjors'),
#  ('Sjors', 'fanquake'),
#  ('jonasschnelli', 'jonasschnelli'),
#  ('MarcoFalke', 'jonasschnelli'),
#  ('MarcoFalke', 'marcoagner'),
#  ('domob1812', 'marcoagner'),
#  ('domob1812', 'domob1812'),
#  ('ken2812221', 'sergeyklay'),
#  ('ken2812221', 'sergeyklay'),
#  ('ken2812221', 'sergeyklay'),
#  ('sergeyklay', 'sergeyklay'),
#  ('fanquake', 'ken2812221'),
#  ('FIVIL', 'fanquake'),
#  ('jonasschnelli', 'melaxon'),
#  ('MeshCollider', 'melaxon'),
#  ('MeshCollider', 'promag'),
#  ('Sjors', 'ken2812221'),
#  ('Sjors', 'ken2812221'),
#  ('Sjors', 'ken2812221'),
#  ('Sjors', 'Sjors'),
#  ('Sjors', 'laanwj'),
#  ('laanwj', 'theuni'),
#  ('Sjors', 'theuni'),
#  ('Sjors', 'jonasschnelli'),
#  ('MarcoFalke', 'jonasschnelli'),
#  ('LucaPaterlini', 'MarcoFalke'),
#  ('LucaPaterlini', 'sipa'),
#  ('LucaPaterlini', 'sipa'),
#  ('LucaPaterlini', 'MarcoFalke'),
#  ('MarcoFalke', 'crowdcoinChain'),
#  ('crowdcoinChain', 'jonasschnelli'),
#  ('MarcoFalke', 'jonasschnelli'),
#  ('MarcoFalke', 'sipsorcery'),
#  ('ZexiFangkong', 'promag'),
#  ('ZexiFangkong', 'fanquake'),
#  ('MarcoFalke', 'MarcoFalke'),
#  ('MarcoFalke', 'jtimon'),
#  ('StayCoolDK', 'efvhi'),
#  ('efvhi', 'sipa'),
#  ('efvhi', 'sipa'),
#  ('efvhi', 'sipa')]

# %%
c_Undirected = Counter([tuple(sorted(i)) for i in data])   #undirected relation  ex: [a,b] == [b,a]

# %%
c_Undirected
# Out:
# Counter({('MeshCollider', 'wuchiachih'): 3,
#          ('sipa', 'wuchiachih'): 1,
#          ('ch4ot1c', 'vinnyvoo'): 5,
#          ('vinnyvoo', 'vinnyvoo'): 1,
#          ('DocOBITCOIN', 'dmchess'): 1,
#          ('hamnaz', 'promag'): 1,
#          ('fanquake', 'hamnaz'): 1,
#          ('bunnguyen2410', 'promag'): 1,
#          ('MarcoFalke', 'bunnguyen2410'): 1,
#          ('MarcoFalke', 'ken2812221'): 3,
#          ('bunnguyen2410', 'e-nexus'): 4,
#          ('MeshCollider', 'bunnguyen2410'): 1,
#          ('jonasschnelli', 'msgilligan'): 1,
#          ('Crypto2', 'ryanofsky'): 1,
#          ('al-maisan', 'ryanofsky'): 1,
#          ('al-maisan', 'promag'): 1,
#          ('nopara73', 'promag'): 10,
#          ('promag', 'promag'): 1,
#          ('RHavar', 'promag'): 3,
#          ('RHavar', 'RHavar'): 1,
#          ('jnewbery', 'promag'): 1,
#          ('jnewbery', 'nopara73'): 2,
#          ('achow101', 'coinsmith'): 1,
#          ('MarcoFalke', 'fanquake'): 1,
#          ('RHavar', 'sipa'): 1,
#          ('MarcoFalke', 'sipa'): 4,
#          ('MarcoFalke', 'jnewbery'): 1,
#          ('RHavar', 'jnewbery'): 1,
#          ('RHavar', 'laanwj'): 1,
#          ('laanwj', 'laanwj'): 4,
#          ('kristapsk', 'laanwj'): 2,
#          ('laanwj', 'promag'): 1,
#          ('RHavar', 'kristapsk'): 1,
#          ('kristapsk', 'promag'): 1,
#          ('jb55', 'nopara73'): 1,
#          ('jb55', 'sipa'): 1,
#          ('jnewbery', 'sipa'): 1,
#          ('MarcoFalke', 'nopara73'): 2,
#          ('nopara73', 'sipa'): 2,
#          ('Sjors', 'sangaman'): 1,
#          ('sangaman', 'sangaman'): 1,
#          ('jonasschnelli', 'theuni'): 2,
#          ('fanquake', 'theuni'): 2,
#          ('ReneFroger', 'assafadar'): 3,
#          ('MarcoFalke', 'isghe'): 1,
#          ('achow101', 'isghe'): 1,
#          ('MarcoFalke', 'RHavar'): 1,
#          ('RHavar', 'fanquake'): 1,
#          ('fanquake', 'sdaftuar'): 1,
#          ('RHavar', 'sdaftuar'): 1,
#          ('ken2812221', 'molxyz'): 4,
#          ('MarcoFalke', 'molxyz'): 2,
#          ('molxyz', 'sipsorcery'): 8,
#          ('molxyz', 'molxyz'): 3,
#          ('MarcoFalke', 'yzhou61'): 1,
#          ('eserlxl', 'yzhou61'): 5,
#          ('Ali8668', 'teknari'): 1,
#          ('MarcoFalke', 'teknari'): 2,
#          ('MarcoFalke', 'MarcoFalke'): 6,
#          ('MarcoFalke', 'sanket1729'): 3,
#          ('laanwj', 'sanket1729'): 1,
#          ('MarcoFalke', 'laanwj'): 4,
#          ('DianJakaWidiawan', 'fanquake'): 1,
#          ('ohhmm', 'scravy'): 2,
#          ('ohhmm', 'sipa'): 1,
#          ('scravy', 'sipa'): 1,
#          ('MarcoFalke', 'ohhmm'): 1,
#          ('jonasschnelli', 'laanwj'): 1,
#          ('greenaddress', 'sanjays95'): 1,
#          ('MarcoFalke', 'giaki3003'): 7,
#          ('giaki3003', 'giaki3003'): 1,
#          ('azetrom', 'sipa'): 1,
#          ('AkioNak', 'laanwj'): 2,
#          ('MarcoFalke', 'coinsmith'): 1,
#          ('coinsmith', 'mmortal03'): 2,
#          ('fanquake', 'ken2812221'): 3,
#          ('fanquake', 'molxyz'): 1,
#          ('AkioNak', 'kallewoof'): 3,
#          ('AkioNak', 'AkioNak'): 1,
#          ('AkioNak', 'practicalswift'): 2,
#          ('practicalswift', 'practicalswift'): 3,
#          ('Empact', 'practicalswift'): 1,
#          ('Empact', 'ryanofsky'): 1,
#          ('kallewoof', 'ryanofsky'): 1,
#          ('kallewoof', 'kallewoof'): 1,
#          ('Empact', 'kallewoof'): 1,
#          ('AkioNak', 'Empact'): 1,
#          ('kallewoof', 'practicalswift'): 3,
#          ('MarcoFalke', 'practicalswift'): 1,
#          ('MarcoFalke', 'ryanofsky'): 1,
#          ('practicalswift', 'ryanofsky'): 3,
#          ('alexander7567', 'ken2812221'): 2,
#          ('alexeyneu', 'fanquake'): 1,
#          ('alexeyneu', 'sipa'): 2,
#          ('MarcoFalke', 'alexeyneu'): 1,
#          ('alexeyneu', 'kirillkovalenko'): 3,
#          ('NicolasDorier', 'NicolasDorier'): 1,
#          ('Ayms', 'MarcoFalke'): 6,
#          ('Ayms', 'fanquake'): 2,
#          ('Ayms', 'sipa'): 1,
#          ('Ayms', 'Ayms'): 2,
#          ('jmcorgan', 'practicalswift'): 1,
#          ('domob1812', 'jmcorgan'): 1,
#          ('domob1812', 'promag'): 3,
#          ('practicalswift', 'promag'): 1,
#          ('domob1812', 'practicalswift'): 1,
#          ('MarcoFalke', 'domob1812'): 1,
#          ('MarcoFalke', 'funasty1985'): 5,
#          ('funasty1985', 'sipa'): 3,
#          ('funasty1985', 'funasty1985'): 1,
#          ('domob1812', 'funasty1985'): 1,
#          ('domob1812', 'sipa'): 1,
#          ('leishman', 'sipa'): 2,
#          ('MarcoFalke', 'leishman'): 1,
#          ('funasty1985', 'ken2812221'): 1,
#          ('achow101', 'sipa'): 1,
#          ('Derek701', 'SearchAndDestroy'): 1,
#          ('SearchAndDestroy', 'TheBlueMatt'): 1,
#          ('TheBlueMatt', 'laanwj'): 1,
#          ('MarcoFalke', 'thelukemccarthy'): 1,
#          ('MarcoFalke', 'cryptozeny'): 1,
#          ('MarcoFalke', 'rhinogroup'): 3,
#          ('MarcoFalke', 'syrius01'): 1,
#          ('sipa', 'syrius01'): 1,
#          ('fanquake', 'isghe'): 1,
#          ('fanquake', 'jonasschnelli'): 2,
#          ('Sjors', 'fanquake'): 2,
#          ('jamesob', 'ken2812221'): 1,
#          ('GusevVasily', 'MarcoFalke'): 2,
#          ('GusevVasily', 'GusevVasily'): 1,
#          ('GusevVasily', 'TheBlueMatt'): 1,
#          ('MarcoFalke', 'TheBlueMatt'): 1,
#          ('kallewoof', 'laanwj'): 1,
#          ('achow101', 'kallewoof'): 1,
#          ('DinoStray', 'jonasschnelli'): 1,
#          ('jonasschnelli', 'nkostoulas'): 1,
#          ('bekarys0504', 'fanquake'): 1,
#          ('Sjors', 'achow101'): 1,
#          ('Sjors', 'ken2812221'): 7,
#          ('Sjors', 'Sjors'): 4,
#          ('MarcoFalke', 'Sjors'): 3,
#          ('jonasschnelli', 'jonasschnelli'): 1,
#          ('MarcoFalke', 'jonasschnelli'): 3,
#          ('MarcoFalke', 'marcoagner'): 1,
#          ('domob1812', 'marcoagner'): 1,
#          ('domob1812', 'domob1812'): 1,
#          ('ken2812221', 'sergeyklay'): 3,
#          ('sergeyklay', 'sergeyklay'): 1,
#          ('FIVIL', 'fanquake'): 1,
#          ('jonasschnelli', 'melaxon'): 1,
#          ('MeshCollider', 'melaxon'): 1,
#          ('MeshCollider', 'promag'): 1,
#          ('Sjors', 'laanwj'): 1,
#          ('laanwj', 'theuni'): 1,
#          ('Sjors', 'theuni'): 1,
#          ('Sjors', 'jonasschnelli'): 1,
#          ('LucaPaterlini', 'MarcoFalke'): 2,
#          ('LucaPaterlini', 'sipa'): 2,
#          ('MarcoFalke', 'crowdcoinChain'): 1,
#          ('crowdcoinChain', 'jonasschnelli'): 1,
#          ('MarcoFalke', 'sipsorcery'): 1,
#          ('ZexiFangkong', 'promag'): 1,
#          ('ZexiFangkong', 'fanquake'): 1,
#          ('MarcoFalke', 'jtimon'): 1,
#          ('StayCoolDK', 'efvhi'): 1,
#          ('efvhi', 'sipa'): 3})

# %%
w = [(key[0],key[1],value) for key,value in c_Undirected.items()]

# %%
w
# Out:
# [('MeshCollider', 'wuchiachih', 3),
#  ('sipa', 'wuchiachih', 1),
#  ('ch4ot1c', 'vinnyvoo', 5),
#  ('vinnyvoo', 'vinnyvoo', 1),
#  ('DocOBITCOIN', 'dmchess', 1),
#  ('hamnaz', 'promag', 1),
#  ('fanquake', 'hamnaz', 1),
#  ('bunnguyen2410', 'promag', 1),
#  ('MarcoFalke', 'bunnguyen2410', 1),
#  ('MarcoFalke', 'ken2812221', 3),
#  ('bunnguyen2410', 'e-nexus', 4),
#  ('MeshCollider', 'bunnguyen2410', 1),
#  ('jonasschnelli', 'msgilligan', 1),
#  ('Crypto2', 'ryanofsky', 1),
#  ('al-maisan', 'ryanofsky', 1),
#  ('al-maisan', 'promag', 1),
#  ('nopara73', 'promag', 10),
#  ('promag', 'promag', 1),
#  ('RHavar', 'promag', 3),
#  ('RHavar', 'RHavar', 1),
#  ('jnewbery', 'promag', 1),
#  ('jnewbery', 'nopara73', 2),
#  ('achow101', 'coinsmith', 1),
#  ('MarcoFalke', 'fanquake', 1),
#  ('RHavar', 'sipa', 1),
#  ('MarcoFalke', 'sipa', 4),
#  ('MarcoFalke', 'jnewbery', 1),
#  ('RHavar', 'jnewbery', 1),
#  ('RHavar', 'laanwj', 1),
#  ('laanwj', 'laanwj', 4),
#  ('kristapsk', 'laanwj', 2),
#  ('laanwj', 'promag', 1),
#  ('RHavar', 'kristapsk', 1),
#  ('kristapsk', 'promag', 1),
#  ('jb55', 'nopara73', 1),
#  ('jb55', 'sipa', 1),
#  ('jnewbery', 'sipa', 1),
#  ('MarcoFalke', 'nopara73', 2),
#  ('nopara73', 'sipa', 2),
#  ('Sjors', 'sangaman', 1),
#  ('sangaman', 'sangaman', 1),
#  ('jonasschnelli', 'theuni', 2),
#  ('fanquake', 'theuni', 2),
#  ('ReneFroger', 'assafadar', 3),
#  ('MarcoFalke', 'isghe', 1),
#  ('achow101', 'isghe', 1),
#  ('MarcoFalke', 'RHavar', 1),
#  ('RHavar', 'fanquake', 1),
#  ('fanquake', 'sdaftuar', 1),
#  ('RHavar', 'sdaftuar', 1),
#  ('ken2812221', 'molxyz', 4),
#  ('MarcoFalke', 'molxyz', 2),
#  ('molxyz', 'sipsorcery', 8),
#  ('molxyz', 'molxyz', 3),
#  ('MarcoFalke', 'yzhou61', 1),
#  ('eserlxl', 'yzhou61', 5),
#  ('Ali8668', 'teknari', 1),
#  ('MarcoFalke', 'teknari', 2),
#  ('MarcoFalke', 'MarcoFalke', 6),
#  ('MarcoFalke', 'sanket1729', 3),
#  ('laanwj', 'sanket1729', 1),
#  ('MarcoFalke', 'laanwj', 4),
#  ('DianJakaWidiawan', 'fanquake', 1),
#  ('ohhmm', 'scravy', 2),
#  ('ohhmm', 'sipa', 1),
#  ('scravy', 'sipa', 1),
#  ('MarcoFalke', 'ohhmm', 1),
#  ('jonasschnelli', 'laanwj', 1),
#  ('greenaddress', 'sanjays95', 1),
#  ('MarcoFalke', 'giaki3003', 7),
#  ('giaki3003', 'giaki3003', 1),
#  ('azetrom', 'sipa', 1),
#  ('AkioNak', 'laanwj', 2),
#  ('MarcoFalke', 'coinsmith', 1),
#  ('coinsmith', 'mmortal03', 2),
#  ('fanquake', 'ken2812221', 3),
#  ('fanquake', 'molxyz', 1),
#  ('AkioNak', 'kallewoof', 3),
#  ('AkioNak', 'AkioNak', 1),
#  ('AkioNak', 'practicalswift', 2),
#  ('practicalswift', 'practicalswift', 3),
#  ('Empact', 'practicalswift', 1),
#  ('Empact', 'ryanofsky', 1),
#  ('kallewoof', 'ryanofsky', 1),
#  ('kallewoof', 'kallewoof', 1),
#  ('Empact', 'kallewoof', 1),
#  ('AkioNak', 'Empact', 1),
#  ('kallewoof', 'practicalswift', 3),
#  ('MarcoFalke', 'practicalswift', 1),
#  ('MarcoFalke', 'ryanofsky', 1),
#  ('practicalswift', 'ryanofsky', 3),
#  ('alexander7567', 'ken2812221', 2),
#  ('alexeyneu', 'fanquake', 1),
#  ('alexeyneu', 'sipa', 2),
#  ('MarcoFalke', 'alexeyneu', 1),
#  ('alexeyneu', 'kirillkovalenko', 3),
#  ('NicolasDorier', 'NicolasDorier', 1),
#  ('Ayms', 'MarcoFalke', 6),
#  ('Ayms', 'fanquake', 2),
#  ('Ayms', 'sipa', 1),
#  ('Ayms', 'Ayms', 2),
#  ('jmcorgan', 'practicalswift', 1),
#  ('domob1812', 'jmcorgan', 1),
#  ('domob1812', 'promag', 3),
#  ('practicalswift', 'promag', 1),
#  ('domob1812', 'practicalswift', 1),
#  ('MarcoFalke', 'domob1812', 1),
#  ('MarcoFalke', 'funasty1985', 5),
#  ('funasty1985', 'sipa', 3),
#  ('funasty1985', 'funasty1985', 1),
#  ('domob1812', 'funasty1985', 1),
#  ('domob1812', 'sipa', 1),
#  ('leishman', 'sipa', 2),
#  ('MarcoFalke', 'leishman', 1),
#  ('funasty1985', 'ken2812221', 1),
#  ('achow101', 'sipa', 1),
#  ('Derek701', 'SearchAndDestroy', 1),
#  ('SearchAndDestroy', 'TheBlueMatt', 1),
#  ('TheBlueMatt', 'laanwj', 1),
#  ('MarcoFalke', 'thelukemccarthy', 1),
#  ('MarcoFalke', 'cryptozeny', 1),
#  ('MarcoFalke', 'rhinogroup', 3),
#  ('MarcoFalke', 'syrius01', 1),
#  ('sipa', 'syrius01', 1),
#  ('fanquake', 'isghe', 1),
#  ('fanquake', 'jonasschnelli', 2),
#  ('Sjors', 'fanquake', 2),
#  ('jamesob', 'ken2812221', 1),
#  ('GusevVasily', 'MarcoFalke', 2),
#  ('GusevVasily', 'GusevVasily', 1),
#  ('GusevVasily', 'TheBlueMatt', 1),
#  ('MarcoFalke', 'TheBlueMatt', 1),
#  ('kallewoof', 'laanwj', 1),
#  ('achow101', 'kallewoof', 1),
#  ('DinoStray', 'jonasschnelli', 1),
#  ('jonasschnelli', 'nkostoulas', 1),
#  ('bekarys0504', 'fanquake', 1),
#  ('Sjors', 'achow101', 1),
#  ('Sjors', 'ken2812221', 7),
#  ('Sjors', 'Sjors', 4),
#  ('MarcoFalke', 'Sjors', 3),
#  ('jonasschnelli', 'jonasschnelli', 1),
#  ('MarcoFalke', 'jonasschnelli', 3),
#  ('MarcoFalke', 'marcoagner', 1),
#  ('domob1812', 'marcoagner', 1),
#  ('domob1812', 'domob1812', 1),
#  ('ken2812221', 'sergeyklay', 3),
#  ('sergeyklay', 'sergeyklay', 1),
#  ('FIVIL', 'fanquake', 1),
#  ('jonasschnelli', 'melaxon', 1),
#  ('MeshCollider', 'melaxon', 1),
#  ('MeshCollider', 'promag', 1),
#  ('Sjors', 'laanwj', 1),
#  ('laanwj', 'theuni', 1),
#  ('Sjors', 'theuni', 1),
#  ('Sjors', 'jonasschnelli', 1),
#  ('LucaPaterlini', 'MarcoFalke', 2),
#  ('LucaPaterlini', 'sipa', 2),
#  ('MarcoFalke', 'crowdcoinChain', 1),
#  ('crowdcoinChain', 'jonasschnelli', 1),
#  ('MarcoFalke', 'sipsorcery', 1),
#  ('ZexiFangkong', 'promag', 1),
#  ('ZexiFangkong', 'fanquake', 1),
#  ('MarcoFalke', 'jtimon', 1),
#  ('StayCoolDK', 'efvhi', 1),
#  ('efvhi', 'sipa', 3)]

# %%
a = []
b = []
c = []
for i in w:
    a.append(i[0])
    b.append(i[1])
    c.append(i[2])
    
dit = {'Source':a, 'Target':b,'Weight':c}
df = pd.DataFrame(dit)
df.to_csv(r'output_for_gephi2',columns=['Source','Target','Weight'],index=False,sep=',')
